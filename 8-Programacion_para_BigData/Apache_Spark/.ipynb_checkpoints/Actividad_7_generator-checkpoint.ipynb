# %% [markdown]
# # Infromation Generator
# fuente original: https://pgirish.github.io/spark-project/index.html

# %%
#importemos la dependecias necesarias:
import socket, sys, requests
try:
    import requests_oauthlib
except:
    # !pip install requests-oauthlib
    import requests_oauthlib
import json
import bleach
from bs4 import BeautifulSoup

# %%
# a la aplicación se le ha dado el nombre de Spark Streaming & tweepy
# creemos las credenciales:
access_token = '1370417521434693638-ctkVVnWxWwJ1BsaDnvvjrnyvkoFBVe'
access_secret = '8qS26rmsPCbfmRREVDdX9DaPmvK4ju6alKetf9f78EpZE'
consumer_key = 'ymZoyMK4ixWqEDF3msyqA02XI' # api Key
consumer_secret = 'w63SEvcNrrvkb6aHhsjvDj3wef56cXMUgLHnL19vxMhhxHUp51' # api secret

# %%
# Creemos la variable de autenticación:
my_auth = requests_oauthlib.OAuth1(consumer_key, consumer_secret, access_token, access_secret)

# %%
# creemos la funcion que obtendrá los twits:
def get_tweets():
    url = 'https://stream.twitter.com/1.1/statuses/filter.json'
    query_data = [('language', 'en'), ('locations', '-130,-20,100,50'),('track','#')]
    query_url = url + '?' + '&'.join([str(t[0]) + '=' + str(t[1]) for t in query_data])
    response = requests.get(query_url, auth=my_auth, stream=True) # obtiene los twits con los datos de autenticacion
    print(query_url, response)
    return response

# %%
# ahora será necesaria una funcion que envie la infromación a spark
def send_tweets_to_spark(http_resp, tcp_connection):
    for line in http_resp.iter_lines():
        try:
            full_tweet = json.loads(line)
            tweet_text = full_tweet['text']# separa el texto del tweet del resto
            print("Tweet Text: " + tweet_text)
            print ("------------------------------------------")
            #tweet_screen_name = "SN:"+full_tweet['user']['screen_name']
            #print("SCREEN NAME IS : " + tweet_screen_name)
            #print ("------------------------------------------")
            #source = full_tweet['source']
            #soup = BeautifulSoup(source)
            #for anchor in soup.find_all('a'):         
            #   print("Tweet Source: " + anchor.text)        
            #tweet_source = anchor.text
            #source_device = tweet_source.replace(" ", "")
            #device = "TS"+source_device.replace("Twitter", "") 
            #print("SOURCE IS : " + device)
            #print ("------------------------------------------")
            tweet_country_code = "CC"+full_tweet['place']['country_code']
            print("COUNTRY CODE IS : " + tweet_country_code)#obtenemos el pais desde el que se ha creado
            print ("------------------------------------------")
            tcp_connection.send(
                tweet_text +' '+ tweet_country_code + ' '+ tweet_screen_name +' '+ device +'\n'
            )# envia la infromacion mediante protoclolo tcp
        except:
            continue

# %%
# creemos ahora la configuración del generador de infromación:
TCP_IP = "localhost" # establecemos la IP
TCP_PORT = 9009 # establecemos el puerto de comunicación
conn = None
s = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
s.bind((TCP_IP, TCP_PORT))
s.listen(1)
print("Waiting for TCP connection...")
conn, addr = s.accept()
print("Connected... Starting getting tweets.")
resp = get_tweets() # obtenemos los tweets
send_tweets_to_spark(resp, conn) #los enviamos a spark mdiante el host y la IP seleccionados
# Out:
# Waiting for TCP connection...
# Connected... Starting getting tweets.
# https://stream.twitter.com/1.1/statuses/filter.json?language=en&locations=-130,-20,100,50&track=# <Response [200]>
# Tweet Text: it sure is a Wednesday
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: @AnitaGrace11 Your dedication is impressive!
# ------------------------------------------
# COUNTRY CODE IS : CCCA
# ------------------------------------------
# Tweet Text: What’s to do on Wednesday’s
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: Ready 4 tomorrow to celebrate with Saudi ppl 🇸🇦🇸🇦💚 https://t.co/pS78XFqHOz
# ------------------------------------------
# COUNTRY CODE IS : CCSA
# ------------------------------------------
# Tweet Text: @ErieNotEerie The choice not to vaccinate
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: @braxton_mccoy Thought I saw a pic of you shirtless with a Bigfoot the other day on here. 😂
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: @HiddenCash New Year
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: Help protect your community and make the world a safer and friendlier place. Apply now to be a Security Guard - Enb… https://t.co/VRi3QvGJPa
# ------------------------------------------
# COUNTRY CODE IS : CCCA
# ------------------------------------------
# Tweet Text: @D_butterflie @EFeromi 🤣🤣🤣
# #FlyGirlMaria
# Maria Chike The Boss
# ------------------------------------------
# COUNTRY CODE IS : CCNG
# ------------------------------------------
# Tweet Text: Indeed, we do exist.
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: @gats813 You'll have the platform lol
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: Mail call! Received a record direct from @helenstellarmusic! So happy to finally have this on vinyl!… https://t.co/tZtwO3gIp5
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: Naw fr!‼️
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: THIS is one hell of a thread.
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: My parents are selling their OU tickets (50-yard line, 55 rows up, east side) for this weekend. Anyone interested?
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: @NastyNelsons @cheetahssv Love this outfit alot. You look very good right here.  Iam glad you are doing well in the… https://t.co/ehQh493VcX
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: @_accaroll Dragon Z
# ------------------------------------------
# COUNTRY CODE IS : CCBR
# ------------------------------------------
# Tweet Text: @iamsrk good night 😴😴😴😴😴😴
# ------------------------------------------
# COUNTRY CODE IS : CCEG
# ------------------------------------------
# Tweet Text: @Ctgamer12 … I’m just having a laugh my bad
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: @jhesson83 @GHSWaveFootball @CoachWatsonGHS @BU_FootballTN @CoachJBrown11 @BIGshadowMIKE thank you!!
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: Very few musicians had as strong a sense of melody as Cobain did. Unfortunately, quite a few have had as much of a… https://t.co/MMwkOdeMBd
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: #Salesforce has released their climate action plan. A blueprint for other companies to follow. #ESG #NetZero today,… https://t.co/nLKJ8zR3bv
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: "I promise I won't cry. It's just a single frame from a tv show."
#
# The single frame: https://t.co/7HmEHmzqrC
# ------------------------------------------
# COUNTRY CODE IS : CCMX
# ------------------------------------------
# Tweet Text: https://t.co/CcY1GwbEdp #GoFundMe The Beast Thanks You All!
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: @JAProsperity @DamionCrawford Nah he posted it for real I saw it on his Fb.
# ------------------------------------------
# COUNTRY CODE IS : CCJM
# ------------------------------------------
# Tweet Text: As soon as I tweet about ice cream, I see this. Now they’re just taunting me.
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: ColorCore™ 10-Pc. Multicolor Cutlery Set with Blade Guards
# ColorCore™ 10-Pc. Multicolor Cutlery Set with Blade Guar… https://t.co/nLrdSYN6Cf
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: Just posted a photo @ Cinemark Cinema 6 https://t.co/eRqwIo75fT
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: Damn 🤔 https://t.co/YlX1yAAXhA
# ------------------------------------------
# COUNTRY CODE IS : CCTZ
# ------------------------------------------
# Tweet Text: @Zachschwartz55 It is a pantheon of mud and silt
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: It won’t be easy to win with this group but the pieces are there if Cora manages them right. I’m excited for this s… https://t.co/aqcGWxJp4J
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: You will be turned away, so I advise you come correct! 🤗 see y’all tomorrow!
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: Tonight we're here at the @NewSettlementNY community center for our reopening celebration! We're starting a new cha… https://t.co/Fldd7S2qrA
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: @TenovaTenChido BOYFRIEND is so solid
# ------------------------------------------
# COUNTRY CODE IS : CCNG
# ------------------------------------------
# Tweet Text: I love this man so much
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: I’m hurt god but I know you got this in your hands ..💕
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: wdym???? breath breath don’t tell me da breath I can’t be YOOO BRING ME A SHOT
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text:
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: For someone to say my smokin is a problem just tells me they really don’t knw me. The fuck. I’m a functioning pot head bitch.
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: @GarcelleB @TheRealDaytime I hope you're having wonderful day.
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: @WestSS_101 @Welcome2Sexland @BleacherReport @MLB You don’t watch much baseball do you?  World Series last year and #1 team in AL this year.
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: Hello fellow criminals .. I’m here to purchase some illegal paraphernalia
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: Things not usually in my freezer. My friend Geoff had to move an entire house of stuff out before he could find a n… https://t.co/hnaOLJeQwo
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: @CallionMonica @DougCarlin2006 Awesome poster
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: Happy Hour Menu at Hang Time Sports Grill and Bar:
# Salmonella  Salsa and Chips Norovirus Nachos w/ a
#  #COVID19 ch… https://t.co/ETYXIfaSPa
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: Anyone wanna get a place and be my roommate by early 2022?
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: this is what the eyes of depression looks like https://t.co/7TQxrbk46H
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: hope you don’t have $600+ in your bank account
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: Smoking🐲 https://t.co/HzvYZkWAxP
# ------------------------------------------
# COUNTRY CODE IS : CCAO
# ------------------------------------------
# Tweet Text: “He’s probably not the type to have social media” “but that’s the kind of guy I want” 😩😭😭
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: We're hiring! Click to apply: Facilities Team Leader - https://t.co/Dg6zhsO4OQ #teamleader #Sacramento, CA
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: I'm at Collingswood High School in Collingswood, NJ https://t.co/EQq6hxqRMH https://t.co/LrAdzn1gY6
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: ❄❄❄❄
# Show yourself
# Step into the power
# Grow yourself
# Into something new
# You are the one you've been waiting for
# All… https://t.co/fUduUayXdm
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: @Susieland_7 @BigPurr43472026 @organotoy I am soooo in
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: TAKE ME BACK!!!!
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: Things that don’t go together- #pineappleonapizza, #cerealandwater, you and unemployment. Need a job in Lakewood, C… https://t.co/Af5CBaFsUo
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: @45Donnie @Wilnerness Carapazza throwing Edwin in out in the first inning of that Canada Day was the worst.
# ------------------------------------------
# COUNTRY CODE IS : CCCA
# ------------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_21606/1307255867.py in <module>
#      10 print("Connected... Starting getting tweets.")
#      11 resp = get_tweets() # obtenemos los tweets
# ---> 12 send_tweets_to_spark(resp, conn) #los enviamos a spark mdiante el host y la IP seleccionados
#
# /tmp/ipykernel_21606/468687092.py in send_tweets_to_spark(http_resp, tcp_connection)
#       1 # ahora será necesaria una funcion que envie la infromación a spark
#       2 def send_tweets_to_spark(http_resp, tcp_connection):
# ----> 3     for line in http_resp.iter_lines():
#       4         try:
#       5             full_tweet = json.loads(line)
#
# /opt/conda/lib/python3.9/site-packages/requests/models.py in iter_lines(self, chunk_size, decode_unicode, delimiter)
#     800         pending = None
#     801
# --> 802         for chunk in self.iter_content(chunk_size=chunk_size, decode_unicode=decode_unicode):
#     803
#     804             if pending is not None:
#
# /opt/conda/lib/python3.9/site-packages/requests/models.py in generate()
#     756             if hasattr(self.raw, 'stream'):
#     757                 try:
# --> 758                     for chunk in self.raw.stream(chunk_size, decode_content=True):
#     759                         yield chunk
#     760                 except ProtocolError as e:
#
# /opt/conda/lib/python3.9/site-packages/urllib3/response.py in stream(self, amt, decode_content)
#     570         """
#     571         if self.chunked and self.supports_chunked_reads():
# --> 572             for line in self.read_chunked(amt, decode_content=decode_content):
#     573                 yield line
#     574         else:
#
# /opt/conda/lib/python3.9/site-packages/urllib3/response.py in read_chunked(self, amt, decode_content)
#     762
#     763             while True:
# --> 764                 self._update_chunk_length()
#     765                 if self.chunk_left == 0:
#     766                     break
#
# /opt/conda/lib/python3.9/site-packages/urllib3/response.py in _update_chunk_length(self)
#     692         if self.chunk_left is not None:
#     693             return
# --> 694         line = self._fp.fp.readline()
#     695         line = line.split(b";", 1)[0]
#     696         try:
#
# /opt/conda/lib/python3.9/socket.py in readinto(self, b)
#     702         while True:
#     703             try:
# --> 704                 return self._sock.recv_into(b)
#     705             except timeout:
#     706                 self._timeout_occurred = True
#
# /opt/conda/lib/python3.9/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1239                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240                   self.__class__)
# -> 1241             return self.read(nbytes, buffer)
#    1242         else:
#    1243             return super().recv_into(buffer, nbytes, flags)
#
# /opt/conda/lib/python3.9/ssl.py in read(self, len, buffer)
#    1097         try:
#    1098             if buffer is not None:
# -> 1099                 return self._sslobj.read(len, buffer)
#    1100             else:
#    1101                 return self._sslobj.read(len)
#
# KeyboardInterrupt:
