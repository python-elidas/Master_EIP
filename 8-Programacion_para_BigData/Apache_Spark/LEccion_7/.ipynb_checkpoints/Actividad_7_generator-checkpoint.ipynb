# %% [markdown]
# # Infromation Generator
# fuente original: https://pgirish.github.io/spark-project/index.html

# %%
#importemos la dependecias necesarias:
import socket, sys, requests
try:
    import requests_oauthlib
except:
    # !pip install requests-oauthlib
    import requests_oauthlib
import json
import bleach
from bs4 import BeautifulSoup
# Out:
# Collecting requests-oauthlib
#   Downloading requests_oauthlib-1.3.0-py2.py3-none-any.whl (23 kB)
# Requirement already satisfied: oauthlib>=3.0.0 in /opt/conda/lib/python3.9/site-packages (from requests-oauthlib) (3.1.1)
# Requirement already satisfied: requests>=2.0.0 in /opt/conda/lib/python3.9/site-packages (from requests-oauthlib) (2.26.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.9/site-packages (from requests>=2.0.0->requests-oauthlib) (2021.5.30)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /opt/conda/lib/python3.9/site-packages (from requests>=2.0.0->requests-oauthlib) (2.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/conda/lib/python3.9/site-packages (from requests>=2.0.0->requests-oauthlib) (1.26.6)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.9/site-packages (from requests>=2.0.0->requests-oauthlib) (3.1)
# Installing collected packages: requests-oauthlib
# Successfully installed requests-oauthlib-1.3.0

# %%
# a la aplicación se le ha dado el nombre de Spark Streaming & tweepy
# creemos las credenciales:
access_token = '1370417521434693638-ctkVVnWxWwJ1BsaDnvvjrnyvkoFBVe'
access_secret = '8qS26rmsPCbfmRREVDdX9DaPmvK4ju6alKetf9f78EpZE'
consumer_key = 'ymZoyMK4ixWqEDF3msyqA02XI' # api Key
consumer_secret = 'w63SEvcNrrvkb6aHhsjvDj3wef56cXMUgLHnL19vxMhhxHUp51' # api secret

# %%
# Creemos la variable de autenticación:
my_auth = requests_oauthlib.OAuth1(consumer_key, consumer_secret, access_token, access_secret)

# %%
# creemos la funcion que obtendrá los twits:
def get_tweets():
    url = 'https://stream.twitter.com/1.1/statuses/filter.json'
    query_data = [('language', 'en'), ('locations', '-130,-20,100,50'),('track','#')]
    query_url = url + '?' + '&'.join([str(t[0]) + '=' + str(t[1]) for t in query_data])
    response = requests.get(query_url, auth=my_auth, stream=True) # obtiene los twits con los datos de autenticacion
    print(query_url, response)
    return response

# %%
# ahora será necesaria una funcion que envie la infromación a spark
def send_tweets_to_spark(http_resp, tcp_connection):
    for line in http_resp.iter_lines():
        try:
            full_tweet = json.loads(line)
            tweet_text = full_tweet['text']# separa el texto del tweet del resto
            print("Tweet Text: " + tweet_text)
            print ("------------------------------------------")
            #tweet_screen_name = "SN:"+full_tweet['user']['screen_name']
            #print("SCREEN NAME IS : " + tweet_screen_name)
            #print ("------------------------------------------")
            source = full_tweet['source']
            soup = BeautifulSoup(source)
            for anchor in soup.find_all('a'):         
               print("Tweet Source: " + anchor.text)        
            tweet_source = anchor.text
            source_device = tweet_source.replace(" ", "")
            device = "TS"+source_device.replace("Twitter", "") 
            print("SOURCE IS : " + device)
            print ("------------------------------------------")
            tweet_country_code = "CC"+full_tweet['place']['country_code']
            print("COUNTRY CODE IS : " + tweet_country_code)#obtenemos el pais desde el que se ha creado
            print ("------------------------------------------")
            tcp_connection.send(
                tweet_text +' '+ tweet_country_code + ' '+ tweet_screen_name +' '+ device +'\n'
            )# envia la infromacion mediante protoclolo tcp
        except:
            continue

# %%
# creemos ahora la configuración del generador de infromación:
TCP_IP = "localhost" # establecemos la IP
TCP_PORT = 9009 # establecemos el puerto de comunicación
conn = None
s = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
s.bind((TCP_IP, TCP_PORT))
s.listen(1)
print("Waiting for TCP connection...")
conn, addr = s.accept()
print("Connected... Starting getting tweets.")
resp = get_tweets() # obtenemos los tweets
send_tweets_to_spark(resp, conn) #los enviamos a spark mdiante el host y la IP seleccionados
# Out:
# Waiting for TCP connection...
# Connected... Starting getting tweets.
# https://stream.twitter.com/1.1/statuses/filter.json?language=en&locations=-130,-20,100,50&track=# <Response [200]>
# Tweet Text: @HelloCullen Line* detail
# ------------------------------------------
# Tweet Source: Twitter for iPhone
# SOURCE IS : TSforiPhone
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: @PrincipalSYoung @itsgabrielleu Okay!!!
# ------------------------------------------
# Tweet Source: Twitter for iPhone
# SOURCE IS : TSforiPhone
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: The music is just 🤌🏻🥲 beaut
# ------------------------------------------
# Tweet Source: Twitter for iPhone
# SOURCE IS : TSforiPhone
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: #MeetTheRams - Welcome to the team, 6’5 Freshman, @Shooter_Deej14 ! DJ is a dynamic guard from Pittsburgh, Pennsylv… https://t.co/JeEYzFmVxc
# ------------------------------------------
# Tweet Source: Twitter for iPhone
# SOURCE IS : TSforiPhone
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: #iPadPro DEFINITELY! The bigger the better 📱✨ What are you most excited about? Vote in @Verizon's… https://t.co/oOfkxiQElC
# ------------------------------------------
# Tweet Source: Twitter for iPhone
# SOURCE IS : TSforiPhone
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: @Regina_Kenney So good!
# ------------------------------------------
# Tweet Source: Twitter for iPhone
# SOURCE IS : TSforiPhone
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: @Captain_8_Hook @TeaPainUSA It's humiliating because it shows how obsessed he was with Obama. He wanted the mattres… https://t.co/NFNRWhW6kz
# ------------------------------------------
# Tweet Source: Twitter for Android
# SOURCE IS : TSforAndroid
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: Expect a 7 year delivery timeframe.
# ------------------------------------------
# Tweet Source: Twitter for iPhone
# SOURCE IS : TSforiPhone
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: Oh no. I’ve been exposed.
# ------------------------------------------
# Tweet Source: Twitter for iPhone
# SOURCE IS : TSforiPhone
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: unfortunately..🤷..i fall too fast, care too much, forgive too easy, wait too long, miss people i shouldn't, worry o… https://t.co/Nlq1MTtRih
# ------------------------------------------
# Tweet Source: Twitter for Android
# SOURCE IS : TSforAndroid
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: 6 Things To Do This Weekend In Cleveland: Sept. 24-26. #WorkHardPlayGard #FallSeason #FamilyTime #Cleveland… https://t.co/cU2FarhedX
# ------------------------------------------
# Tweet Source: Twitter for iPhone
# SOURCE IS : TSforiPhone
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: Way to be WELL SPOKEN Scholar @caden_2022 Johnson @Coach_TsTock @FDouglassFB @arclayjohn
# ------------------------------------------
# Tweet Source: Twitter for iPhone
# SOURCE IS : TSforiPhone
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: @Jorgeridesagain @dread_rocco @RossRic29761382 @DianneIrby @dickbaldin @FazzyMom @SailorMan612 You too bud
# ------------------------------------------
# Tweet Source: Twitter for iPhone
# SOURCE IS : TSforiPhone
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: @chaiiwalii I mean mA
# ------------------------------------------
# Tweet Source: Twitter for iPhone
# SOURCE IS : TSforiPhone
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: @Sorryimshelbyyy @MelissaYeo3 @JeffreeStar @KelliYeOo you are such a doll! 🌈😘❤️😘💋💋💋🌈🥰🥰🥰
# ------------------------------------------
# Tweet Source: Twitter for iPhone
# SOURCE IS : TSforiPhone
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: @st3v3turn3r @sherylwillwrite @NeedlesOnNews @fyfemillar Was there no policy put in place regarding this when ranked ballot was adopted?
# ------------------------------------------
# Tweet Source: Twitter for iPhone
# SOURCE IS : TSforiPhone
# ------------------------------------------
# COUNTRY CODE IS : CCCA
# ------------------------------------------
# Tweet Text: @BigGameBoomer @gamecocktoday "Seattle" https://t.co/s3iA70dPrL
# ------------------------------------------
# Tweet Source: Twitter for Android
# SOURCE IS : TSforAndroid
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: Return to your bisexual roots this #BiVisibilityDay by looking at pictures of Megan Fox and Dean Winchester and buy… https://t.co/7sH84tbGSU
# ------------------------------------------
# Tweet Source: Twitter for iPhone
# SOURCE IS : TSforiPhone
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: @theyshootactors I can't wait for the GPC to get rid of AP.
# ------------------------------------------
# Tweet Source: Twitter for Android
# SOURCE IS : TSforAndroid
# ------------------------------------------
# COUNTRY CODE IS : CCCA
# ------------------------------------------
# Tweet Text: @incompleteocean @pissoffhoser @maqart55 @annaeck73 @OldTimeyCrazy @_cynde__ @virginia_house @daimondog @ednasdiner… https://t.co/PPYUkhyQIK
# ------------------------------------------
# Tweet Source: Twitter for iPhone
# SOURCE IS : TSforiPhone
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: I wish I kept all my wallet tickets 😩. Im@always deleting something.
# ------------------------------------------
# Tweet Source: Twitter for iPhone
# SOURCE IS : TSforiPhone
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: The owner of my company: “Wow you are doing more than what we pay you for!”
#
# ….pay me more then 🥴
# ------------------------------------------
# Tweet Source: Twitter for iPhone
# SOURCE IS : TSforiPhone
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: yes still do…..
# ------------------------------------------
# Tweet Source: Twitter for iPhone
# SOURCE IS : TSforiPhone
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: @malakiteo Keep balling Malaki, I am a big fan
# ------------------------------------------
# Tweet Source: Twitter for iPhone
# SOURCE IS : TSforiPhone
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: Just posted a photo @ Cactus Taproom Beer &amp; Wine Bar https://t.co/vhlrZkOCRe
# ------------------------------------------
# Tweet Source: Instagram
# SOURCE IS : TSInstagram
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: @Walter_XVIII @ATLFaZe Okay cool I thought so cause I did the same.
# ------------------------------------------
# Tweet Source: Twitter for iPhone
# SOURCE IS : TSforiPhone
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: Boris OhNo
# ------------------------------------------
# Tweet Source: Twitter for iPhone
# SOURCE IS : TSforiPhone
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: I have an electric car and I still visit @KwikTrip more than anyone I know. #HomeAwayFromHome
# ------------------------------------------
# Tweet Source: Twitter for Android
# SOURCE IS : TSforAndroid
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: now why i look up from my book to see the man sitting in front of me “taking a selfie” but my face is the only one… https://t.co/QvkfapU5Zb
# ------------------------------------------
# Tweet Source: Twitter for iPhone
# SOURCE IS : TSforiPhone
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: ✨Win 30,000 $KST Tokens from @KSMStarter and @MoonBootsCap!
#
# KSM Starter is the premier launchpad for $KSM.  Join o… https://t.co/xNsL1l5F5c
# ------------------------------------------
# Tweet Source: Twitter for Android
# SOURCE IS : TSforAndroid
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: Foodfort at JUMP🧆🍲
# Join us this Friday and Saturday for Treefort celebration classes and meetups.
# -“Drink Beer, Sav… https://t.co/T6juPLKVMj
# ------------------------------------------
# Tweet Source: Twitter for iPhone
# SOURCE IS : TSforiPhone
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: @FeedeeKelly I want to suck it
# ------------------------------------------
# Tweet Source: Twitter for Android
# SOURCE IS : TSforAndroid
# ------------------------------------------
# COUNTRY CODE IS : CCPK
# ------------------------------------------
# Tweet Text: The relationship between me and black clothes is something that can’t be explained. 🖤
# ------------------------------------------
# Tweet Source: Twitter for iPhone
# SOURCE IS : TSforiPhone
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: @JamaalStreet @SGVNSports USC commit
# ------------------------------------------
# Tweet Source: Twitter for iPhone
# SOURCE IS : TSforiPhone
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: @MAliLeonard Yes i feel fine and normal. My arm don’t even hurt
# ------------------------------------------
# Tweet Source: Twitter for iPhone
# SOURCE IS : TSforiPhone
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: @Letsgamble23 If they went crazy I'd be worried.
# ------------------------------------------
# Tweet Source: Twitter for Android
# SOURCE IS : TSforAndroid
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: I left a urine sample at Palmdale regional hospital they clipped they kept clearing my brains they said they were p… https://t.co/ie4frp3XMo
# ------------------------------------------
# Tweet Source: Twitter for iPhone
# SOURCE IS : TSforiPhone
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: Stupid
# ------------------------------------------
# Tweet Source: Twitter for iPhone
# SOURCE IS : TSforiPhone
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: @_TrapTunez @deche_milburn Don’t say nothing else. It will show on Saturday against a ranked opponent. Because i al… https://t.co/ZTZ2ygPGYb
# ------------------------------------------
# Tweet Source: Twitter for iPhone
# SOURCE IS : TSforiPhone
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: @MR_STiXX Don’t be giving these ideas away for free Jordan…
# ------------------------------------------
# Tweet Source: Twitter for iPhone
# SOURCE IS : TSforiPhone
# ------------------------------------------
# COUNTRY CODE IS : CCCA
# ------------------------------------------
# Tweet Text: @shirlolaaa If I say don’t come to Indy, you gone come? Lol
# ------------------------------------------
# Tweet Source: Twitter for iPhone
# SOURCE IS : TSforiPhone
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: if twitter has taught me anything it is that the hottest girls are always on the verge of death
# ------------------------------------------
# Tweet Source: Twitter for iPhone
# SOURCE IS : TSforiPhone
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: @ash_kaashh follow me I want to reply to yo shit
# ------------------------------------------
# Tweet Source: Twitter for iPhone
# SOURCE IS : TSforiPhone
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: @dysmorphia_wb When I first saw the pictures I thought a raspberry jam container exploded in your face
# ------------------------------------------
# Tweet Source: Twitter for Android
# SOURCE IS : TSforAndroid
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: Keiara is a straight comedian, this girl be having me hollering 😂😂
# ------------------------------------------
# Tweet Source: Twitter for iPhone
# SOURCE IS : TSforiPhone
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: Your house is on fire.  #SWfutures
# ------------------------------------------
# Tweet Source: Twitter for iPhone
# SOURCE IS : TSforiPhone
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: People that say, "tax the rich!" make no sense to me.
#
# That money will go to the federal govt. A govt once lead by… https://t.co/DWoDrw3zYT
# ------------------------------------------
# Tweet Source: Twitter for Android
# SOURCE IS : TSforAndroid
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: Cleared: Construction on #US1 SB at Washington Rd
# ------------------------------------------
# Tweet Source: 511NY-Tweets
# SOURCE IS : TS511NY-Tweets
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: @konypyon @NightingaleEden Mom we need more sunflower seeds, peeled pls
# ------------------------------------------
# Tweet Source: Twitter for Android
# SOURCE IS : TSforAndroid
# ------------------------------------------
# COUNTRY CODE IS : CCES
# ------------------------------------------
# Tweet Text: Should have done my homework but this was my first year actually diving into the #toppsgypsyqueen line. Fell in lov… https://t.co/XsPGC6vZtb
# ------------------------------------------
# Tweet Source: Twitter for Android
# SOURCE IS : TSforAndroid
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: Cleared: Construction on #NJ55 SB from North of Exit 24 - NJ 49 to South of Exit 24 - NJ 49
# ------------------------------------------
# Tweet Source: 511NY-Tweets
# SOURCE IS : TS511NY-Tweets
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: So what you're saying is... https://t.co/7syX2s2od5
# ------------------------------------------
# Tweet Source: Twitter for Android
# SOURCE IS : TSforAndroid
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: Fact 💪🏿 💥
# ------------------------------------------
# Tweet Source: Twitter for iPhone
# SOURCE IS : TSforiPhone
# ------------------------------------------
# COUNTRY CODE IS : CCSN
# ------------------------------------------
# Tweet Text: LOL we have 2 in our campaign. 1 just gave birth.
# ------------------------------------------
# Tweet Source: Twitter for Android
# SOURCE IS : TSforAndroid
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: Cleared: Construction on #NJ24 EB at West of Exit 7 - NJ 124/JFK Parkway
# ------------------------------------------
# Tweet Source: 511NY-Tweets
# SOURCE IS : TS511NY-Tweets
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: @VikingBarbie_ Watch out for mosquitoes
# ------------------------------------------
# Tweet Source: Twitter for Android
# SOURCE IS : TSforAndroid
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: @ScottCandage it's working... i'm totally triggered to the point of suicide... someone should tell them that if the… https://t.co/imZz5nnweT
# ------------------------------------------
# Tweet Source: Twitter for Android
# SOURCE IS : TSforAndroid
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: Incident on #GardenStateParkway SB at North of Exit 83 - US 9 North https://t.co/0Clw6XZEMp
# ------------------------------------------
# Tweet Source: 511NY-Tweets
# SOURCE IS : TS511NY-Tweets
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: Because: She's Not White!
# ------------------------------------------
# Tweet Source: Twitter for Android
# SOURCE IS : TSforAndroid
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: Amala and Ewedu is the bomb 😋😋😋 https://t.co/pi44wd9SAL
# ------------------------------------------
# Tweet Source: Twitter for Android
# SOURCE IS : TSforAndroid
# ------------------------------------------
# COUNTRY CODE IS : CCNG
# ------------------------------------------
# Tweet Text: Want to work at TJX Companies, Inc.? We're hiring in #Dartmouth, MA! Click the link in our bio for details on this… https://t.co/CAaWymGuSf
# ------------------------------------------
# Tweet Source: CareerArc 2.0
# SOURCE IS : TSCareerArc2.0
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: This #Actuarial job might be a great fit for you. Click the link in our bio to see it and more. Senior SAP Function… https://t.co/se4prS3Dzb
# ------------------------------------------
# Tweet Source: CareerArc 2.0
# SOURCE IS : TSCareerArc2.0
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: Just posted a photo @ AmeriStop Waynesville https://t.co/3hFAyFCBUY
# ------------------------------------------
# Tweet Source: Instagram
# SOURCE IS : TSInstagram
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: @BrunswickBeCooo Hope they give me 5 Baja Blasts
# ------------------------------------------
# Tweet Source: Twitter for iPhone
# SOURCE IS : TSforiPhone
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: @CryptoMonkeyKi1 0x42D126F974b3DA99A078F8788eF939BE16bE6EA7
# ------------------------------------------
# Tweet Source: Twitter for iPhone
# SOURCE IS : TSforiPhone
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: Stop staring at the clock every day. It's time for a new career. Follow us to view jobs with titles like "Warehouse… https://t.co/wclV3yQhir
# ------------------------------------------
# Tweet Source: CareerArc 2.0
# SOURCE IS : TSCareerArc2.0
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: Prisma Health is hiring in #Greenville, SC! Read about our latest #IT job opening via the link in our bio: Research Data Coordinator Senior
# ------------------------------------------
# Tweet Source: CareerArc 2.0
# SOURCE IS : TSCareerArc2.0
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: Alert: STRUCTURE FIRE @ 660 ATWOOD AV N Tac: E Sent: E4 D10
# ------------------------------------------
# Tweet Source: Pinellas County 911 App
# SOURCE IS : TSPinellasCounty911App
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: @whitesox win the 2021 AL Central Division https://t.co/qs0xUFzr7t
# ------------------------------------------
# Tweet Source: Twitter for iPhone
# SOURCE IS : TSforiPhone
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: MTC is hiring in #Kuna, ID! Read about our latest #corrections job opening via the link in our bio: Correctional Officer
# ------------------------------------------
# Tweet Source: CareerArc 2.0
# SOURCE IS : TSCareerArc2.0
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: acab except Fritter the K9 https://t.co/CbHJ348HNY
# ------------------------------------------
# Tweet Source: Twitter for iPhone
# SOURCE IS : TSforiPhone
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: Have you ever had a role like "Coin Machine Operator MAYWOOD, NJ"? What did you like most about that job? #security #Maywood, NJ
# ------------------------------------------
# Tweet Source: CareerArc 2.0
# SOURCE IS : TSCareerArc2.0
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: I'm sorry but Reputation was a great album. I don't care what anyone says. It was so much better than Lover. And it… https://t.co/W5Zk5SqlNB
# ------------------------------------------
# Tweet Source: Twitter for Android
# SOURCE IS : TSforAndroid
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: if these mf’s don’t get my momma home soon, this has been the longest two months of my life 😩
# ------------------------------------------
# Tweet Source: Twitter for iPhone
# SOURCE IS : TSforiPhone
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: Of course they did. We need to stop worrying about vaccinating more people and focus on therapeutics that work. All… https://t.co/9kLNh6kv1q
# ------------------------------------------
# Tweet Source: Twitter for iPhone
# SOURCE IS : TSforiPhone
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: S/O to @melanyrenee for the Barnes &amp; Noble suggestion. Was basically driving around Hampton Roads hitting up grocer… https://t.co/gyuIAqMyai
# ------------------------------------------
# Tweet Source: Twitter for iPhone
# SOURCE IS : TSforiPhone
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: @Jaiyejejeomo You fine sha, but i fine pass you.
# ------------------------------------------
# Tweet Source: Twitter for Android
# SOURCE IS : TSforAndroid
# ------------------------------------------
# COUNTRY CODE IS : CCNG
# ------------------------------------------
# Tweet Text: Finally got some signal at the camp grounds‼️
#
# Besides the rain when we got here, the vibes atm are fucking immacul… https://t.co/PSJtvcCpWi
# ------------------------------------------
# Tweet Source: Twitter for iPhone
# SOURCE IS : TSforiPhone
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: @mehdi_dissem @defaultquit Eiiii mr. tomorrow
# ------------------------------------------
# Tweet Source: Twitter for Android
# SOURCE IS : TSforAndroid
# ------------------------------------------
# COUNTRY CODE IS : CCGH
# ------------------------------------------
# Tweet Text: @jonathan_v33 I've been watching dreadfully awful baseball all my life. At least this team has the ability to do so… https://t.co/q70VqXLPlK
# ------------------------------------------
# Tweet Source: Twitter for Android
# SOURCE IS : TSforAndroid
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: “The first 3 Championships were Bill Belichick. The last 3 were Tom Brady” I couldn’t agree more
# ------------------------------------------
# Tweet Source: Twitter for iPhone
# SOURCE IS : TSforiPhone
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: "Circle got smaller everybody can't go" - Nipsey Hustle 🖤🖤🖤🖤💪💪💪💪🇧🇸🇧🇸🇧🇸🇧🇸🌎🌏🌍 @ Harbour Island, Harbour Island, Baham… https://t.co/yMOMEfPhxt
# ------------------------------------------
# Tweet Source: Instagram
# SOURCE IS : TSInstagram
# ------------------------------------------
# COUNTRY CODE IS : CCBS
# ------------------------------------------
# Tweet Text: throwin a house show for @btmbrkt at the crib. DM for address 🙇🏻‍♂️
# ------------------------------------------
# Tweet Source: Twitter for iPhone
# SOURCE IS : TSforiPhone
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: Where is everybody #Gambia
# ------------------------------------------
# Tweet Source: Twitter for iPhone
# SOURCE IS : TSforiPhone
# ------------------------------------------
# COUNTRY CODE IS : CCGM
# ------------------------------------------
# Tweet Text: @ngelecheijep I watched 1 ep cos you stood me up and the other one I’d watched in Zanzibar by mistake😭😭😭😭 o let’s s… https://t.co/yZwF83PoV8
# ------------------------------------------
# Tweet Source: Twitter for iPhone
# SOURCE IS : TSforiPhone
# ------------------------------------------
# COUNTRY CODE IS : CCKE
# ------------------------------------------
# Tweet Text: Today for international sign language day. I want to say that I am thankful for ASL. I’m thankful for those who tau… https://t.co/SdxJMo9lLF
# ------------------------------------------
# Tweet Source: Twitter for iPhone
# SOURCE IS : TSforiPhone
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: Ew it’s going to be in the 70s again next week, gross
# ------------------------------------------
# Tweet Source: Twitter for iPhone
# SOURCE IS : TSforiPhone
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: We don’t want to tell our dreams , we want to show them.
# ------------------------------------------
# Tweet Source: Twitter for iPhone
# SOURCE IS : TSforiPhone
# ------------------------------------------
# COUNTRY CODE IS : CCTR
# ------------------------------------------
# Tweet Text: But they in fact do not hold their bros accountable and their bros continue to terrorize women 🤠
# ------------------------------------------
# Tweet Source: Twitter for iPhone
# SOURCE IS : TSforiPhone
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: @steveconaway1 Sounds like living a lavish lifestyle and greed finally caught up with the family
# ------------------------------------------
# Tweet Source: Twitter for iPhone
# SOURCE IS : TSforiPhone
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: New wines at Mayhew continue. Introducing Stefan Massone’s Masera Gavi. Made in a tiny commune in Italy, this delic… https://t.co/zfXOb2Xkw3
# ------------------------------------------
# Tweet Source: Twitter for iPhone
# SOURCE IS : TSforiPhone
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: @ruffini_chelsea !!! who u tellin.
# ------------------------------------------
# Tweet Source: Twitter for iPhone
# SOURCE IS : TSforiPhone
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: Finally reaching the finish line on my website. It’s currently, “https://t.co/uqZyY56cCa”, but will be,“… https://t.co/OIMlK5LcdS
# ------------------------------------------
# Tweet Source: Twitter for iPhone
# SOURCE IS : TSforiPhone
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: We just made our soon to be 3 niece  an email account 🥺our aim as her dope aunties @greenfairyy_ , is to give her u… https://t.co/yjoko9i1t5
# ------------------------------------------
# Tweet Source: Twitter for iPhone
# SOURCE IS : TSforiPhone
# ------------------------------------------
# COUNTRY CODE IS : CCZM
# ------------------------------------------
# Tweet Text: rich off pain
# ------------------------------------------
# Tweet Source: Twitter for iPhone
# SOURCE IS : TSforiPhone
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: 🏴󠁵󠁳󠁴󠁸󠁿Stacey
# 0466440707267454008254qrst https://t.co/I7QBDzQoPj
# ------------------------------------------
# Tweet Source: Twitter for Android
# SOURCE IS : TSforAndroid
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: @JudahTheHammer @philipaklein B.S.
#  Must be inhaling too much of the Dem poisonous gas you breathe into your  usele… https://t.co/HRdCXeDBlK
# ------------------------------------------
# Tweet Source: Twitter for Android
# SOURCE IS : TSforAndroid
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: Any suggestions for sever side pagination @npmjs in @angular?
#
# #angular
# ------------------------------------------
# Tweet Source: Twitter for iPhone
# SOURCE IS : TSforiPhone
# ------------------------------------------
# COUNTRY CODE IS : CCPK
# ------------------------------------------
# Tweet Text: Day in #LagunaBeach 🌴 https://t.co/6we4MdeVC4
# ------------------------------------------
# Tweet Source: Twitter for iPhone
# SOURCE IS : TSforiPhone
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: @HighDefDiscNews There was me, that is Alex, and my three droogs, that is Pete, Georgie, and Dim, and we sat in the… https://t.co/y3ND50B97G
# ------------------------------------------
# Tweet Source: Twitter for Android
# SOURCE IS : TSforAndroid
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: don't give me any pets again, I'm not good for this😔👋
# ------------------------------------------
# Tweet Source: Twitter for Android
# SOURCE IS : TSforAndroid
# ------------------------------------------
# COUNTRY CODE IS : CCPE
# ------------------------------------------
# Tweet Text: Toss up between Friday night lights and narcos Mexico
# ------------------------------------------
# Tweet Source: Twitter for iPhone
# SOURCE IS : TSforiPhone
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: Definitely going to the gym later
# ------------------------------------------
# Tweet Source: Twitter for iPhone
# SOURCE IS : TSforiPhone
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: Positive energy and attitude is sexy to me!!!!
# Head Scarf and Robe from @SDesirebrand
# Use Code Sherell to save som… https://t.co/GCL6z33zLM
# ------------------------------------------
# Tweet Source: Twitter for Android
# SOURCE IS : TSforAndroid
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: This👇👇👇
# ------------------------------------------
# Tweet Source: Twitter for iPhone
# SOURCE IS : TSforiPhone
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: Join me in my Space! https://t.co/Lt29sXetHZ
# ------------------------------------------
# Tweet Source: Twitter for iPhone
# SOURCE IS : TSforiPhone
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: @julieverhage @CharleyMa Hahahaha oh boy I hope Charley asks you about your thoughts 😂👀
# ------------------------------------------
# Tweet Source: Twitter for iPhone
# SOURCE IS : TSforiPhone
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: @M4kkTruck I can see her in this
# ------------------------------------------
# Tweet Source: Twitter for Android
# SOURCE IS : TSforAndroid
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: son holy shit
# ------------------------------------------
# Tweet Source: Twitter for iPhone
# SOURCE IS : TSforiPhone
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: @pasha_hsb (hugs)
# ------------------------------------------
# Tweet Source: Twitter for iPhone
# SOURCE IS : TSforiPhone
# ------------------------------------------
# COUNTRY CODE IS : CCGE
# ------------------------------------------
# Tweet Text: Tesco warns of Christmas panic buying if driver shortage persists https://t.co/BiXOX2VQZf
# ------------------------------------------
# Tweet Source: Twitter for Android
# SOURCE IS : TSforAndroid
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: Congratulations @rmarjunr for being recognized with @EnrollmentORG’s Rising Star Award. Plus, you clearly win the a… https://t.co/I44Xw0bYVu
# ------------------------------------------
# Tweet Source: Twitter for iPhone
# SOURCE IS : TSforiPhone
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: Just posted a photo @ Salt Lake City, Utah https://t.co/7wm4AnX9Ap
# ------------------------------------------
# Tweet Source: Instagram
# SOURCE IS : TSInstagram
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: @KVUE Maybe we should line those up along the border. Might be cheaper than a wall. Our tax dollars at work. Could… https://t.co/B4OB5pMlaF
# ------------------------------------------
# Tweet Source: Twitter for Android
# SOURCE IS : TSforAndroid
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: @mzsey_ Person wey get fine legs na ein wey dey worship 😹😹😹
# ------------------------------------------
# Tweet Source: Twitter for iPhone
# SOURCE IS : TSforiPhone
# ------------------------------------------
# COUNTRY CODE IS : CCGH
# ------------------------------------------
# Tweet Text: Every-time you say “what is @DetroitCityFC gonna do next?”…they do stuff like this…incredible!
# ------------------------------------------
# Tweet Source: Twitter for iPhone
# SOURCE IS : TSforiPhone
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: this iOS 15 spatial audio for music update is messing with my head
# ------------------------------------------
# Tweet Source: Twitter for iPhone
# SOURCE IS : TSforiPhone
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: We’re about to see hyperinflation happen in the next few weeks, 20/hr about to be the new minimum wage 🥲🙃
# ------------------------------------------
# Tweet Source: Twitter for iPhone
# SOURCE IS : TSforiPhone
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: @BadDisneyAdvice Our local @McDonalds told us they can’t sell the toys w/o buying a Happy Meal 🤬
# ------------------------------------------
# Tweet Source: Twitter for iPhone
# SOURCE IS : TSforiPhone
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: @HeartsOfOakGH have not received any official information from FIFA about automatic qualification to the CCL group… https://t.co/JfTnsrfU0J
# ------------------------------------------
# Tweet Source: Twitter for Android
# SOURCE IS : TSforAndroid
# ------------------------------------------
# COUNTRY CODE IS : CCGH
# ------------------------------------------
# Tweet Text: No camera again this week; but serving as a journalist covering the appointment of Parliamentary Secretaries in The… https://t.co/vBAcQGfIDA
# ------------------------------------------
# Tweet Source: Twitter for Android
# SOURCE IS : TSforAndroid
# ------------------------------------------
# COUNTRY CODE IS : CCBS
# ------------------------------------------
# Tweet Text: @TheLeoTerrell @YouTube Go back to Harlem https://t.co/tCp3V8nnWS
# ------------------------------------------
# Tweet Source: Twitter for iPhone
# SOURCE IS : TSforiPhone
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: unfortunately..🤷..i fall too fast, care too much, forgive too easy, wait too long, miss people i shouldn't, worry o… https://t.co/C2qlrt6P6B
# ------------------------------------------
# Tweet Source: Twitter for Android
# SOURCE IS : TSforAndroid
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: “Unless large-scale decarceration measures are implemented, epidemics––of coronavirus but also much else––inside ca… https://t.co/qFmWCWkYfD
# ------------------------------------------
# Tweet Source: Twitter for iPhone
# SOURCE IS : TSforiPhone
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: Just posted a video @ Ipaja, Lagos, Nigeria https://t.co/U94OAEEO82
# ------------------------------------------
# Tweet Source: Instagram
# SOURCE IS : TSInstagram
# ------------------------------------------
# COUNTRY CODE IS : CCNG
# ------------------------------------------
# Tweet Text: @joehussung You’re right 🙏
# ------------------------------------------
# Tweet Source: Twitter for iPhone
# SOURCE IS : TSforiPhone
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: Yall better not 😭😭💀 https://t.co/2pFH9N6CTU
# ------------------------------------------
# Tweet Source: Twitter for iPhone
# SOURCE IS : TSforiPhone
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: @brukti_2304 @berhe_lucy @AJEnglish @PowerUSAID @SecBlinken @POTUS r blinded while z truth is surfaced!… https://t.co/s6tKbjQ9e2
# ------------------------------------------
# Tweet Source: Twitter for Android
# SOURCE IS : TSforAndroid
# ------------------------------------------
# COUNTRY CODE IS : CCET
# ------------------------------------------
# Tweet Text: @Len76311350 @JackPosobiec I can't stand her. Big f**king baby
# ------------------------------------------
# Tweet Source: Twitter for Android
# SOURCE IS : TSforAndroid
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: @JeffMarek How ugly does this get?
# ------------------------------------------
# Tweet Source: Twitter for iPhone
# SOURCE IS : TSforiPhone
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: I’m definitely more creative with makeup, food, and art in general when I’m in this state of mind 🧚🏼‍♀️
# ------------------------------------------
# Tweet Source: Twitter for iPhone
# SOURCE IS : TSforiPhone
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: RIP James Bissionette a 2005 graduate of A-M from Covid!! Good guy knew him from school &amp; seeing him in the communi… https://t.co/qhKTooFGB7
# ------------------------------------------
# Tweet Source: Twitter for Android
# SOURCE IS : TSforAndroid
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: The driver 32TLR30790 blocked the bike lane near 520 2nd Ave on September 22. This is in Manhattan Community Board… https://t.co/2500du5CHu
# ------------------------------------------
# Tweet Source: Reported_NYC
# SOURCE IS : TSReported_NYC
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: God has a funny way of forcing us to slow down in order to stop and take in all that life has to offer. Thank you G… https://t.co/WNV9GnFIPX
# ------------------------------------------
# Tweet Source: Twitter for iPhone
# SOURCE IS : TSforiPhone
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: Getting closer! Make sure to get your team signed up! https://t.co/mlwLm59zta
# ------------------------------------------
# Tweet Source: Twitter for iPhone
# SOURCE IS : TSforiPhone
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: @colinwe49573922 @Dirk_Niblick @thesportsdweeb @BuckIProduction @JEDRICKWlLLS @RaineyMyCloser For one, claiming tha… https://t.co/VnH4gfJ42g
# ------------------------------------------
# Tweet Source: Twitter for iPhone
# SOURCE IS : TSforiPhone
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: 🔥🔥🔥 already kno this one gone be
# ------------------------------------------
# Tweet Source: Twitter for iPhone
# SOURCE IS : TSforiPhone
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: @sljivana Isto.
# ------------------------------------------
# Tweet Source: Twitter for iPhone
# SOURCE IS : TSforiPhone
# ------------------------------------------
# COUNTRY CODE IS : CCRS
# ------------------------------------------
# Tweet Text: It’s better to keep me as a friend then a enemy…
# ------------------------------------------
# Tweet Source: Twitter for iPhone
# SOURCE IS : TSforiPhone
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: The Atlantic: No, Vaccinated People Are Not ‘Just as Likely’ to Spread the Coronavirus as Unvaccinated People.… https://t.co/gY8Su9lSNl
# ------------------------------------------
# Tweet Source: Twitter for Android
# SOURCE IS : TSforAndroid
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: This weather has got me 🥱 😴
# ------------------------------------------
# Tweet Source: Twitter for iPhone
# SOURCE IS : TSforiPhone
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: “Yea that sick Nigga biggie with the 8-shot fifth, with the extra clip for that extra shit.”
# ------------------------------------------
# Tweet Source: Twitter for iPhone
# SOURCE IS : TSforiPhone
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: @1followernodad In the book definitely
# ------------------------------------------
# Tweet Source: Twitter for iPhone
# SOURCE IS : TSforiPhone
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: Beer. Out of the bottle, out of the can. You be the judge. 🤔
# ------------------------------------------
# Tweet Source: Twitter for iPhone
# SOURCE IS : TSforiPhone
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: Think about for 3 days then ask me 🤪
# ------------------------------------------
# Tweet Source: Twitter for iPhone
# SOURCE IS : TSforiPhone
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: Making tiktoks in my car is my highlight of the day
# ------------------------------------------
# Tweet Source: Twitter for iPhone
# SOURCE IS : TSforiPhone
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: Looking to score a job at QVC? You're in luck. Click the link in our bio for the job description and information on… https://t.co/OdirYwqSCQ
# ------------------------------------------
# Tweet Source: CareerArc 2.0
# SOURCE IS : TSCareerArc2.0
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: My horse show husband in training, heart horse, and I at the Kentucky Horse Park this morning for our first show. 🥰 https://t.co/3LMlc3iuiO
# ------------------------------------------
# Tweet Source: Twitter for iPhone
# SOURCE IS : TSforiPhone
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: sometimes i think a show is personally testing me to see if i will say mean things and i simply cannot take the bait
# ------------------------------------------
# Tweet Source: Twitter for iPhone
# SOURCE IS : TSforiPhone
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: 26 years ago today, we were married.
# 5 houses, 4 children, 3 dogs and 19 nervous breakdowns later, and we're still… https://t.co/7qa77WED3f
# ------------------------------------------
# Tweet Source: Twitter for iPhone
# SOURCE IS : TSforiPhone
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: I’ve been Normalizing doing everything ALONE even though i don’t like to. But as i get OLDER I see why i HAVE TO!
# ------------------------------------------
# Tweet Source: Twitter for iPhone
# SOURCE IS : TSforiPhone
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: @lfishgirl67 @StephenM Far worse now. Obama was still president in 16!
# ------------------------------------------
# Tweet Source: Twitter for iPhone
# SOURCE IS : TSforiPhone
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: @CodyKlineSD @PadFathers619 Awesome....
# ------------------------------------------
# Tweet Source: Twitter for Android
# SOURCE IS : TSforAndroid
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: @teddydirusso @Balenciracks "forcing sexuality"..... so the kid should be given a chance to try being a girl first… https://t.co/sVQRM4hVZf
# ------------------------------------------
# Tweet Source: Twitter for Android
# SOURCE IS : TSforAndroid
# ------------------------------------------
# COUNTRY CODE IS : CCKE
# ------------------------------------------
# Tweet Text: Interested in a job in #Baltimore, MD? This could be a great fit: https://t.co/QJtotdtdNs #Mortgage
# ------------------------------------------
# Tweet Source: CareerArc 2.0
# SOURCE IS : TSCareerArc2.0
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: Fix ya credit. Drink water. Take trips. Pay ya bills. Stay outta sucka shit.
# ------------------------------------------
# Tweet Source: Twitter for Android
# SOURCE IS : TSforAndroid
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# ...
# ------------------------------------------
# Tweet Source: Twitter for iPhone
# SOURCE IS : TSforiPhone
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: it’s up there
# ------------------------------------------
# Tweet Source: Echofon
# SOURCE IS : TSEchofon
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: You can blame that on your State’s Governor.
#
# He needs to do better.
# ------------------------------------------
# Tweet Source: Twitter for iPhone
# SOURCE IS : TSforiPhone
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: Pull up @ 5 Pop-Up Shop w/ @fadeoutoffical 🕯@1ofnonestudios ✝️ &amp; @webclothing 🕸 Dm for location @ Houston, Texas https://t.co/BwoOiJbfh1
# ------------------------------------------
# Tweet Source: Instagram
# SOURCE IS : TSInstagram
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: @MikeReiss Love his pocket presence.  Guys going to be amazing.
# ------------------------------------------
# Tweet Source: Twitter for iPhone
# SOURCE IS : TSforiPhone
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: @nowin2613 @TuftThomas @Nataya @beckythecyclist Yes, I realize that that’s a Dr Who GIF. 😊
# ------------------------------------------
# Tweet Source: Twitter for iPhone
# SOURCE IS : TSforiPhone
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: @James85340992 Amen!
# ------------------------------------------
# Tweet Source: Twitter for Android
# SOURCE IS : TSforAndroid
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: @bearz1066 @BigBearF1 Hola Merv have good evening.
# ------------------------------------------
# Tweet Source: Twitter for iPhone
# SOURCE IS : TSforiPhone
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: Life's a bitch if you don't do the right things. #justsaying #Truth #DAM
# ------------------------------------------
# Tweet Source: Twitter for Android
# SOURCE IS : TSforAndroid
# ------------------------------------------
# COUNTRY CODE IS : CCCA
# ------------------------------------------
# Tweet Text: BurgersSheWrote ✨ https://t.co/UDzRdB4Ovg
# ------------------------------------------
# Tweet Source: Twitter for iPhone
# SOURCE IS : TSforiPhone
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: Every month I pretend I win and buy *ALL THE YARN THINGS* for the shop. Maybe some groceries too. And fix that ratt… https://t.co/nJMUx21RSN
# ------------------------------------------
# Tweet Source: Twitter for iPhone
# SOURCE IS : TSforiPhone
# ------------------------------------------
# COUNTRY CODE IS : CCCA
# ------------------------------------------
# Tweet Text: @JPFinlayNBCS Would not fields or Jones give us more hope for the future then Davis    When we get a franchise qb w… https://t.co/9jUfihUczW
# ------------------------------------------
# Tweet Source: Twitter for iPad
# SOURCE IS : TSforiPad
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: @prezstar2 @COL_James83 Family proclamation and the day Joseph finally got the golden plates are the same day! 🙌🏻
# ------------------------------------------
# Tweet Source: Twitter for iPhone
# SOURCE IS : TSforiPhone
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: May I please get 2 followers to copy and re-post this tweet? I'm trying to demonstrate that someone is always liste… https://t.co/Cwqin1YFQy
# ------------------------------------------
# Tweet Source: Twitter for Android
# SOURCE IS : TSforAndroid
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: Another iPhone snap from @fugees25 last night at @pier17ny for @glblctzn @ Club Getaway https://t.co/tlCijIIuaw
# ------------------------------------------
# Tweet Source: Instagram
# SOURCE IS : TSInstagram
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: @JasonSharp16 LMFAO I was gonna text you about this 💀💀💀💀
# ------------------------------------------
# Tweet Source: Twitter for iPhone
# SOURCE IS : TSforiPhone
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: @dhcbaseball happy birthday big guy! No jokes today, just celebration. Hate to let you know it’s one day after the… https://t.co/UttmMacnlY
# ------------------------------------------
# Tweet Source: Twitter for iPhone
# SOURCE IS : TSforiPhone
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: Drinking a Not So Basic Beach by @cahababrewing at @cahababrewing — https://t.co/yvpadXX73T
# ------------------------------------------
# Tweet Source: Untappd
# SOURCE IS : TSUntappd
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: @annemariexrose I look like an egg bro
# ------------------------------------------
# Tweet Source: Twitter for iPhone
# SOURCE IS : TSforiPhone
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: @jGuati09 @barstoolsports @UnnecRoughness @PodfathersShow @detroit_jason You would be correct🤣
# ------------------------------------------
# Tweet Source: Twitter for Android
# SOURCE IS : TSforAndroid
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: @Toniterp Yes we want to learn Toni. If you do a video series we would be happy to subscribe.
# ------------------------------------------
# Tweet Source: Twitter for Android
# SOURCE IS : TSforAndroid
# ------------------------------------------
# COUNTRY CODE IS : CCJM
# ------------------------------------------
# Tweet Text: Nothing stops us! #TruNorth #TFNPRIDE #HSPE #TFNPE https://t.co/0DKjSYfllb
# ------------------------------------------
# Tweet Source: Twitter for iPhone
# SOURCE IS : TSforiPhone
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: Drinking a dHop5 by @eqbrewery at @endlessbrews — https://t.co/RkEKFdpLC8
# ------------------------------------------
# Tweet Source: Untappd
# SOURCE IS : TSUntappd
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: Congratulations to our District Tournament Champions!!! What a great feat by our golfers! On to Regionals, Monday 9… https://t.co/GeBvnBAUt3
# ------------------------------------------
# Tweet Source: Twitter for iPhone
# SOURCE IS : TSforiPhone
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: i give my heart &amp;&amp; that’s the problem.
# ------------------------------------------
# Tweet Source: Twitter for iPhone
# SOURCE IS : TSforiPhone
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: Do it!
# Double dog dare you@to do it!
# Triple dog dare - DO IT!
# ------------------------------------------
# Tweet Source: Twitter for iPhone
# SOURCE IS : TSforiPhone
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: Time to equalize the wealth!
# ------------------------------------------
# Tweet Source: Twitter for Android
# SOURCE IS : TSforAndroid
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: Just posted a photo @ Vancouver, British Columbia https://t.co/sKPKkrfHF2
# ------------------------------------------
# Tweet Source: Instagram
# SOURCE IS : TSInstagram
# ------------------------------------------
# COUNTRY CODE IS : CCCA
# ------------------------------------------
# Tweet Text: @naughtykellie Like me much your tasty delicious cock my love i wish suck i love it
# ------------------------------------------
# Tweet Source: Twitter for Android
# SOURCE IS : TSforAndroid
# ------------------------------------------
# COUNTRY CODE IS : CCMX
# ------------------------------------------
# Tweet Text: dreams do come true 🤍 https://t.co/5HEpBppMlD
# ------------------------------------------
# Tweet Source: Twitter for iPhone
# SOURCE IS : TSforiPhone
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: With unknown sources on income
# ------------------------------------------
# Tweet Source: Twitter for iPhone
# SOURCE IS : TSforiPhone
# ------------------------------------------
# COUNTRY CODE IS : CCUG
# ------------------------------------------
# Tweet Text: ily Robert Downey Jr. but goodbye.
# ------------------------------------------
# Tweet Source: Twitter for iPhone
# SOURCE IS : TSforiPhone
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: Oh man @SBTribune finally going to digital subscriptions. It was a good run.
# ------------------------------------------
# Tweet Source: Twitter for Android
# SOURCE IS : TSforAndroid
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: @Bruisey Let them loose! Great pics
# ------------------------------------------
# Tweet Source: Twitter for iPhone
# SOURCE IS : TSforiPhone
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: Loosin my cool..
# ------------------------------------------
# Tweet Source: Twitter for iPhone
# SOURCE IS : TSforiPhone
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: A good evening everyone and see you tomorrow. Always have a smile... kisses @RealDeanCain https://t.co/MTYTZsi92K
# ------------------------------------------
# Tweet Source: Twitter for Android
# SOURCE IS : TSforAndroid
# ------------------------------------------
# COUNTRY CODE IS : CCFR
# ------------------------------------------
# Tweet Text: @SamDeBrule @jleeku @heyday_hq Just curious, signed up for the beta so I can self serve these answers in future!
# ------------------------------------------
# Tweet Source: Twitter for iPhone
# SOURCE IS : TSforiPhone
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: @fakehistoryhunt @toktalks @RealEarthParty @badasslocs @madanboukman The next century was known has the helenizatio… https://t.co/dovzoLvoY2
# ------------------------------------------
# Tweet Source: Twitter for Android
# SOURCE IS : TSforAndroid
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: I'm 16 years in, I'm pass that phase. I was washing dishes and taking trash out and didn't realize it slid off my f… https://t.co/ugoriLoPZ5
# ------------------------------------------
# Tweet Source: Twitter for iPhone
# SOURCE IS : TSforiPhone
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: Drinking a Fogponix by Hazelwood Brewing Company @ Hazelwood — https://t.co/3JkHcn1H5l
# ------------------------------------------
# Tweet Source: Untappd
# SOURCE IS : TSUntappd
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: @guybranum @DEADLINE @billyeichner OMG OMG OMG THIS IS A DREAM 😭💕 CONGRATS!!!!! 😍
# ------------------------------------------
# Tweet Source: Twitter for iPhone
# SOURCE IS : TSforiPhone
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: @merl_jayy It helped me pass physics
# ------------------------------------------
# Tweet Source: Twitter for iPhone
# SOURCE IS : TSforiPhone
# ------------------------------------------
# COUNTRY CODE IS : CCBW
# ------------------------------------------
# Tweet Text: @Wilketta1 @DrewLawDesign I knew we shared a special bond @Wilketta1 https://t.co/Sz5VoNU397
# ------------------------------------------
# Tweet Source: Twitter for iPhone
# SOURCE IS : TSforiPhone
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: @SInow @Jaberuski @MiLB When you lie on your resume and still get the job.
# ------------------------------------------
# Tweet Source: Twitter for iPhone
# SOURCE IS : TSforiPhone
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: @RickChapterTwo This poor pup has Degenerative Myleopathy.
# ------------------------------------------
# Tweet Source: Twitter for Android
# SOURCE IS : TSforAndroid
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: For real.
# ------------------------------------------
# Tweet Source: Twitter for iPhone
# SOURCE IS : TSforiPhone
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: I love my job but today was such a shitty work day, I’m eggsausted.
# ------------------------------------------
# Tweet Source: Twitter for iPhone
# SOURCE IS : TSforiPhone
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: David , Noel and I from the other night. Absolutely not edited in any way https://t.co/W0VJ5XnXJk
# ------------------------------------------
# Tweet Source: Twitter for iPhone
# SOURCE IS : TSforiPhone
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: I’ve been doing hair all week 🤪
# ------------------------------------------
# Tweet Source: Twitter for iPhone
# SOURCE IS : TSforiPhone
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: @reformadad I def get why some wait. We're gonna find out early at least until we have one of each. I think after t… https://t.co/bjLT2I7sLf
# ------------------------------------------
# Tweet Source: Twitter for Android
# SOURCE IS : TSforAndroid
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: That’s it that’s all
# ------------------------------------------
# Tweet Source: Twitter for iPhone
# SOURCE IS : TSforiPhone
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: Dude is gonna fail big time
# ------------------------------------------
# Tweet Source: Twitter for Android
# SOURCE IS : TSforAndroid
# ------------------------------------------
# COUNTRY CODE IS : CCNG
# ------------------------------------------
# Tweet Text: @buttfucker1200 @SharonDunten @EricBoehlert I do wish more people worried about cancer and other health issues from… https://t.co/HZMMknAMe2
# ------------------------------------------
# Tweet Source: Twitter for Android
# SOURCE IS : TSforAndroid
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
# Tweet Text: I want to get a raspado and drive up to A mountain
# ------------------------------------------
# Tweet Source: Twitter for iPhone
# SOURCE IS : TSforiPhone
# ------------------------------------------
# COUNTRY CODE IS : CCUS
# ------------------------------------------
